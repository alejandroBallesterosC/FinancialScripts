# %% [markdown]
# # A. Import Dependencies

# %%
import pandas as pd
import sklearn as sk
import numpy as np
import time
import datetime as dt
import requests
from operator import add, sub
import matplotlib.pyplot as plt
from pandas.tseries.holiday import AbstractHolidayCalendar, Holiday, nearest_workday, \
    USMartinLutherKingJr, USPresidentsDay, GoodFriday, USMemorialDay, \
    USLaborDay, USThanksgivingDay
from polygon import RESTClient
from statsmodels.graphics.gofplots import qqplot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-96-733015bfafcb> in <module>
#      11     USLaborDay, USThanksgivingDay
#      12 from polygon import RESTClient
# ---> 13 from statsmodels.graphics.gofplots import qqplot
#
# ModuleNotFoundError: No module named 'statsmodels'

# %% [markdown]
# # B. Obtain Data

# %% [markdown]
# ## I. Check the Close/Open Price Data Format

# %%
security = 'SKYY'#ticker
key = ''#insert API Key Here
client = RESTClient(key)
resp = client.stocks_equities_daily_open_close(security, "2020-03-12")
resp.__dict__
# Out:
# {'status': 'OK',
#  'from_': '2020-03-12',
#  'symbol': 'SKYY',
#  'open': 48.84,
#  'high': 51.08,
#  'low': 47.81,
#  'close': 48.01,
#  'volume': 1392154,
#  'after_hours': 51.66,
#  'preMarket': 49.04}

# %% [markdown]
# ## II. Set End Date and Number of Days Back to Obtain Data

# %%
end_date = dt.date(2020, 6, 18)
num_days_back = 7300#should be atleast 101 days (to have atleast 100 samples of a 2-day holding period),
#if you want to look at 3-day holding periods, you will need atleast 102 days, etc.

# %% [markdown]
# ## III. Create a DF of Days to Check Close Prices

# %%
start_date = end_date-dt.timedelta(days=num_days_back)
trading_years = np.linspace(start_date.year, end_date.year, end_date.year-start_date.year + 1).astype(int)
datelist = pd.bdate_range(end=end_date, periods=num_days_back)
df = pd.DataFrame(index=datelist)
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [1992-06-26 00:00:00, 1992-06-29 00:00:00, 1992-06-30 00:00:00, 1992-07-01 00:00:00, 1992-07-02 00:00:00]

# %% [markdown]
# ## IV. Class/Function to create DF w Indices of Trading Holidays for removal From Main DF
# ### (So we don't make calls to the API for data from these days since it would raise an error)

# %%
class USTradingCalendar(AbstractHolidayCalendar):
    rules = [
        Holiday('NewYearsDay', month=1, day=1, observance=nearest_workday),
        USMartinLutherKingJr,
        USPresidentsDay,
        GoodFriday,
        USMemorialDay,
        Holiday('USIndependenceDay', month=7, day=4, observance=nearest_workday),
        USLaborDay,
        USThanksgivingDay,
        Holiday('Christmas', month=12, day=25, observance=nearest_workday)
    ]

def get_trading_close_holidays(year):
    inst = USTradingCalendar()
    return inst.holidays(dt.datetime(year-1, 12, 31), dt.datetime(year, 12, 31))

# %% [markdown]
# ## V. Remove the Trading Holidays From the Main DF We'll Use to Make Calls to the API

# %%
for year in trading_years:
    holidays = get_trading_close_holidays(year)
    df.drop(holidays, errors='ignore', inplace=True)
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [1992-06-26 00:00:00, 1992-06-29 00:00:00, 1992-06-30 00:00:00, 1992-07-01 00:00:00, 1992-07-02 00:00:00]

# %% [markdown]
# ## VI. Make Calls to the API to Get Close Prices on These Days

# %%
close_price_list = []
no_data_days = []
for day in df.index:
    try:
        close_price_list.append(client.stocks_equities_daily_open_close(security, day.date().isoformat()).close)
    except requests.HTTPError as exception:
        no_data_days.append(day)
    finally:
        continue
df.drop(no_data_days, inplace=True)
df['Close Price'] = close_price_list
# Out:
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-06-26?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-06-29?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-06-30?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-01?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-02?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-03?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-06?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-07?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-08?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-09?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-10?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-13?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-14?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-15?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-16?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-17?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-20?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-21?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-22?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-23?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-24?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-27?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-28?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-29?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-30?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-07-31?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-03?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-04?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-05?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-06?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-07?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-10?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-11?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-12?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-13?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-14?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-17?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-18?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-19?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-20?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-21?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-24?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-25?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-26?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-27?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-28?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-08-31?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-01?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-02?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-03?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-04?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-07?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-08?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-09?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-10?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-11?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-14?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-15?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-16?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-17?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-18?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-21?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-22?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-23?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-24?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-25?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-28?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-29?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-09-30?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-01?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-02?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-05?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-06?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-07?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-08?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-09?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-12?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-13?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-14?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-15?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-16?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-19?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-20?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-21?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-22?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-23?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-26?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-27?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-28?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-29?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-10-30?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-02?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-03?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-04?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-05?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-06?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-09?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-10?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-11?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-12?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-13?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-16?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-17?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-18?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-19?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-20?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-23?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-24?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-25?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-26?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-27?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-11-30?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-01?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-02?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-03?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-04?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-07?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-08?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-09?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-10?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-11?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-14?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-15?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-16?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-17?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-18?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-21?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-22?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-23?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-24?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-25?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-28?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-29?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-30?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1992-12-31?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-01?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-04?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-05?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-06?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-07?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-08?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-11?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-12?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-13?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-14?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-15?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-18?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-19?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-20?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-21?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-22?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-25?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-26?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-27?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-28?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-01-29?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-01?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-02?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-03?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-04?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-05?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-08?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-09?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-10?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-11?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-12?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-15?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-16?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-17?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-18?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-19?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-22?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-23?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-24?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-25?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-02-26?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-01?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-02?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-03?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-04?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-05?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-08?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-09?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-10?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-11?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-12?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-15?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-16?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-17?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-18?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-19?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-22?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-23?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-24?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-25?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-26?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-29?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-30?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-03-31?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-01?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-02?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-05?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-06?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-07?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-08?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-09?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-12?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-13?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-14?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-15?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-16?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-19?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-20?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-21?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-22?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-23?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-26?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-27?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-28?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-29?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-04-30?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-03?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-04?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-05?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-06?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-07?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-10?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-11?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-12?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-13?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-14?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-17?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-18?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-19?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-20?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-21?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-24?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-25?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-26?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-27?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-28?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-05-31?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-01?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-02?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-03?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-04?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-07?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-08?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-09?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-10?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-11?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-14?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-15?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-16?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-17?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-18?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-21?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-22?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-23?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-24?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-25?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-28?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-29?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-06-30?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-01?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-02?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-05?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-06?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-07?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-08?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-09?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-12?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-13?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-14?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-15?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-16?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-19?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-20?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-21?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-22?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-23?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-26?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-27?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-28?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-29?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-07-30?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-02?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-03?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-04?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-05?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-06?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-09?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-10?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-11?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-12?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-13?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-16?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-17?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-18?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-19?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-20?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-23?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-24?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-25?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-26?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-27?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-30?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-08-31?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-09-01?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-09-02?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-09-03?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-09-06?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-09-07?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-09-08?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-09-09?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-09-10?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-09-13?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-09-14?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-09-15?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-09-16?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-09-17?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-09-20?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-09-21?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/1993-09-22?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# ...
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-02-04?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-02-07?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-02-08?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-02-09?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-02-10?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-02-11?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-02-14?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-02-15?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-02-16?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-02-17?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-02-18?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-02-22?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-02-23?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-02-24?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-02-25?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-02-28?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-01?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-02?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-03?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-04?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-07?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-08?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-09?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-10?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-11?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-14?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-15?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-16?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-17?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-18?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-21?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-22?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-23?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-24?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-25?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-28?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-29?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-30?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-03-31?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-01?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-04?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-05?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-06?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-07?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-08?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-11?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-12?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-13?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-14?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-15?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-18?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-19?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-20?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-21?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-25?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-26?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-27?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-28?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-04-29?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-02?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-03?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-04?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-05?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-06?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-09?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-10?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-11?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-12?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-13?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-16?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-17?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-18?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-19?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-20?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-23?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-24?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-25?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-26?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-27?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-05-31?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-01?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-02?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-03?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-06?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-07?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-08?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-09?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-10?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-13?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-14?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-15?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-16?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-17?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-20?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-21?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-22?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-23?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-24?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-27?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-28?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-29?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-06-30?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-07-01?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2011-07-05?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2012-10-29?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2012-10-30?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2016-10-05?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d
# 500 Server Error: Internal Server Error for url: https://api.polygon.io/v1/open-close/SKYY/2018-12-05?apiKey=vetnjcAE_Ql7R_OBo1a529HpeAGQkdsynV6u_d

# %%
df.head()
# Out:
#             Close Price
# 2011-07-06        20.29
# 2011-07-07        20.51
# 2011-07-08        20.42
# 2011-07-11        19.91
# 2011-07-12        19.69

# %%
df.tail()
# Out:
#             Close Price
# 2020-06-12        69.17
# 2020-06-15        70.74
# 2020-06-16        72.05
# 2020-06-17        71.94
# 2020-06-18        72.72

# %% [markdown]
# # C. Analysis

# %% [markdown]
# ## I. Plot Data

# %%
df.plot(kind='line',color='red')
plt.title('Closing Price vs Time for ' + str(security))
plt.show()

# %% [markdown]
# ## II. Set Minimum Sample Size for all Holding Periods

# %%
total_days = df.size
min_sample_size = 100 #minimum number of holding periods to look at each iteration
max_num_days_in_curr_holding_period = total_days-min_sample_size+1
num_days_in_curr_holding_period = 2

# %%
#days_offset = total_days%num_days_in_curr_holding_period#calculate number of days by which to offset the first holding period from the start of the data
#indices = list(map(add, first_indices_to_get, len(indices_to_get) * [holding_period * num_days_in_curr_holding_period]))

# %% [markdown]
# ## III. Obtain Price Data, Compute Returns, Expected Return, Standard Deviation of Returns for all Holding Periods

# %% [markdown]
# ### (Use unsorted dictionaries for faster computation)

# %%
returns_dic = {}
standard_deviations_dic = {}
return_expectations_dic = {}
while num_days_in_curr_holding_period <= max_num_days_in_curr_holding_period:
    num_holding_periods = total_days-num_days_in_curr_holding_period + 1#number of holding periods of n days in data set
    indices = list(range(num_days_in_curr_holding_period))#initialize indices to first n days
    returns = []
    for holding_period in range(num_holding_periods):
        close_price_data = df.iloc[indices]
        returns.append((close_price_data.iloc[close_price_data.size-1].at['Close Price']/close_price_data.iloc[0].at['Close Price']) - 1)
        indices = list(map(add, indices, len(indices) * [1]))#add one to each index (list version of index+=1)
    returns_dic[num_days_in_curr_holding_period] = returns
    return_expectations_dic[num_days_in_curr_holding_period] = np.mean(returns)
    standard_deviations_dic[num_days_in_curr_holding_period] = np.std(returns, ddof=1)#sample standard deviation
    num_days_in_curr_holding_period += 1

# %% [markdown]
# ## IV. Sort Unsorted Dictionaries with Data for Plotting

# %%
returns_sorted = sorted(returns_dic.items()) # sorted by key, return a list of tuples
num_days_held, returns = zip(*returns_sorted) # unpack a list of pairs into two tuples

return_expectations = sorted(return_expectations_dic.items()) # sorted by key, return a list of tuples
num_days_held, return_expectations = zip(*return_expectations) # unpack a list of pairs into two tuples

standard_deviations = sorted(standard_deviations_dic.items()) # sorted by key, return a list of tuples
num_days_held, standard_deviations = zip(*standard_deviations) # unpack a list of pairs into two tuples

# %% [markdown]
# ## V. Plot Data

# %%
plt.plot(num_days_held, return_expectations)
plt.title('Expectation of Return VS Holding Period for ' + str(security))
plt.show()

# %%
plt.plot(num_days_held, standard_deviations)
plt.title('Sample Standard Deviation of Returns VS Holding Period for ' + str(security))
plt.show()

# %%
plt.hist(returns_dic[2], bins = 20)
plt.title ('Histogram of 2-Day Holding Period Returns for ' + str(security))
plt.show()

# %%
plt.hist(returns_dic[total_days//2], bins = 20)
plt.title('Histogram of ' + str(total_days//2) +\
          '-Day Holding Period Returns for ' + str(security))
plt.show()

# %%
plt.hist(returns_dic[700], bins = 20)
plt.title('Histogram 700-day Holding Period Returns for ' + str(security))
plt.show()

# %%
lower_estimate = [a - 2*b for a, b in zip(return_expectations, standard_deviations)]
plt.plot(num_days_held, lower_estimate)
plt.title('Expectation of Return Minus Two Sample Standard Deviations VS Holding Period for ' + str(security))
plt.show()

# %% [markdown]
# ## Create  A QQ Plot to Test for Normality

# %%
# QQ plot
qqplot(returns_dic[1500], line='s')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-8395829d56c7> in <module>
#       1 # QQ plot
# ----> 2 qqplot(returns_dic[1500], line='s')
#       3 plt.show()
#
# NameError: name 'qqplot' is not defined
